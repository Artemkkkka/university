# %%
import numpy as np
import pandas as pd
import pickle   # сохранение модели

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn import svm
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error as mse, r2_score as r2
from sklearn.metrics import roc_auc_score, roc_curve, auc, confusion_matrix,  accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('train_lr_2_processed.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Annual Income                   7500 non-null   float64
#  1   Tax Liens                       7500 non-null   float64
#  2   Number of Open Accounts         7500 non-null   float64
#  3   Years of Credit History         7500 non-null   float64
#  4   Maximum Open Credit             7500 non-null   float64
#  5   Number of Credit Problems       7500 non-null   float64
#  6   Months since last delinquent    7500 non-null   float64
#  7   Bankruptcies                    7500 non-null   float64
#  8   Current Loan Amount             7500 non-null   float64
#  9   Current Credit Balance          7500 non-null   float64
#  10  Monthly Debt                    7500 non-null   float64
#  11  Credit Score                    7500 non-null   float64
#  12  Credit Default                  7500 non-null   int64
#  13  Home Ownership_Home Mortgage    7500 non-null   bool
#  14  Home Ownership_Own Home         7500 non-null   bool
#  15  Home Ownership_Rent             7500 non-null   bool
#  16  Years in current job_1 year     7500 non-null   bool
#  17  Years in current job_10+ years  7500 non-null   bool
#  18  Years in current job_2 years    7500 non-null   bool
#  19  Years in current job_3 years    7500 non-null   bool
#  20  Years in current job_4 years    7500 non-null   bool
#  21  Years in current job_5 years    7500 non-null   bool
#  22  Years in current job_6 years    7500 non-null   bool
#  23  Years in current job_7 years    7500 non-null   bool
#  24  Years in current job_8 years    7500 non-null   bool
#  25  Years in current job_9 years    7500 non-null   bool
#  26  Years in current job_< 1 year   7500 non-null   bool
#  27  Purpose_buy a car               7500 non-null   bool
#  28  Purpose_buy house               7500 non-null   bool
#  29  Purpose_debt consolidation      7500 non-null   bool
#  30  Purpose_educational expenses    7500 non-null   bool
#  31  Purpose_home improvements       7500 non-null   bool
#  32  Purpose_major purchase          7500 non-null   bool
#  33  Purpose_medical bills           7500 non-null   bool
#  34  Purpose_moving                  7500 non-null   bool
#  35  Purpose_other                   7500 non-null   bool
#  36  Purpose_renewable energy        7500 non-null   bool
#  37  Purpose_small business          7500 non-null   bool
#  38  Purpose_take a trip             7500 non-null   bool
#  39  Purpose_vacation                7500 non-null   bool
#  40  Purpose_wedding                 7500 non-null   bool
#  41  Term_Short Term                 7500 non-null   bool
# dtypes: bool(29), float64(12), int64(1)
# memory usage: 974.2 KB

# %%
feature_names = df.drop(columns=['Credit Default', 'Purpose_renewable energy']).columns.tolist()
target_name = 'Credit Default'
df = df[feature_names + [target_name]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Annual Income                   7500 non-null   float64
#  1   Tax Liens                       7500 non-null   float64
#  2   Number of Open Accounts         7500 non-null   float64
#  3   Years of Credit History         7500 non-null   float64
#  4   Maximum Open Credit             7500 non-null   float64
#  5   Number of Credit Problems       7500 non-null   float64
#  6   Months since last delinquent    7500 non-null   float64
#  7   Bankruptcies                    7500 non-null   float64
#  8   Current Loan Amount             7500 non-null   float64
#  9   Current Credit Balance          7500 non-null   float64
#  10  Monthly Debt                    7500 non-null   float64
#  11  Credit Score                    7500 non-null   float64
#  12  Home Ownership_Home Mortgage    7500 non-null   bool
#  13  Home Ownership_Own Home         7500 non-null   bool
#  14  Home Ownership_Rent             7500 non-null   bool
#  15  Years in current job_1 year     7500 non-null   bool
#  16  Years in current job_10+ years  7500 non-null   bool
#  17  Years in current job_2 years    7500 non-null   bool
#  18  Years in current job_3 years    7500 non-null   bool
#  19  Years in current job_4 years    7500 non-null   bool
#  20  Years in current job_5 years    7500 non-null   bool
#  21  Years in current job_6 years    7500 non-null   bool
#  22  Years in current job_7 years    7500 non-null   bool
#  23  Years in current job_8 years    7500 non-null   bool
#  24  Years in current job_9 years    7500 non-null   bool
#  25  Years in current job_< 1 year   7500 non-null   bool
#  26  Purpose_buy a car               7500 non-null   bool
#  27  Purpose_buy house               7500 non-null   bool
#  28  Purpose_debt consolidation      7500 non-null   bool
#  29  Purpose_educational expenses    7500 non-null   bool
#  30  Purpose_home improvements       7500 non-null   bool
#  31  Purpose_major purchase          7500 non-null   bool
#  32  Purpose_medical bills           7500 non-null   bool
#  33  Purpose_moving                  7500 non-null   bool
#  34  Purpose_other                   7500 non-null   bool
#  35  Purpose_small business          7500 non-null   bool
#  36  Purpose_take a trip             7500 non-null   bool
#  37  Purpose_vacation                7500 non-null   bool
#  38  Purpose_wedding                 7500 non-null   bool
#  39  Term_Short Term                 7500 non-null   bool
#  40  Credit Default                  7500 non-null   int64
# dtypes: bool(28), float64(12), int64(1)
# memory usage: 966.9 KB

# %%
feature_names_for_stand = df[feature_names].select_dtypes(include=['float64', 'int64']).columns.tolist()
scaler = StandardScaler()
stand_features = scaler.fit_transform(df[feature_names_for_stand])

# %%
df[feature_names_for_stand] = pd.DataFrame(stand_features, columns=feature_names_for_stand)

# %%
df['Credit Default'].value_counts()
# Out:
# Credit Default
# 0    5387
# 1    2113
# Name: count, dtype: int64

# %%
X = df[feature_names]
y = df[target_name]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=42,  stratify=y)

# %%
display(y_train.value_counts(normalize=True),
y_test.value_counts(normalize=True))
# Out:
# Credit Default
# 0    0.718209
# 1    0.281791
# Name: proportion, dtype: float64
# Credit Default
# 0    0.718384
# 1    0.281616
# Name: proportion, dtype: float64

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_train = logreg.predict(X_train)
pred_test = logreg.predict(X_test)

# %%
get_classification_report(y_train, pred_train, y_test, pred_test)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.84      3609
#            1       0.57      0.10      0.17      1416
#
#     accuracy                           0.73      5025
#    macro avg       0.65      0.54      0.50      5025
# weighted avg       0.69      0.73      0.65      5025
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.84      1778
#            1       0.59      0.10      0.17       697
#
#     accuracy                           0.73      2475
#    macro avg       0.66      0.54      0.50      2475
# weighted avg       0.69      0.73      0.65      2475
#
# CONFUSION MATRIX
#
# col_0              0   1
# Credit Default
# 0               1729  49
# 1                627  70

# %%
vectmach = svm.SVC()
vectmach.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred_train = vectmach.predict(X_train)
pred_test = vectmach.predict(X_test)

# %%
get_classification_report(y_train, pred_train, y_test, pred_test)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84      3609
#            1       1.00      0.04      0.08      1416
#
#     accuracy                           0.73      5025
#    macro avg       0.86      0.52      0.46      5025
# weighted avg       0.80      0.73      0.63      5025
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.84      1778
#            1       0.60      0.01      0.02       697
#
#     accuracy                           0.72      2475
#    macro avg       0.66      0.50      0.43      2475
# weighted avg       0.69      0.72      0.61      2475
#
# CONFUSION MATRIX
#
# col_0              0  1
# Credit Default
# 0               1774  4
# 1                691  6

# %%
GB = GradientBoostingClassifier(n_estimators=100, learning_rate=1,
                                 max_depth=5, random_state=2)
GB.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1, max_depth=5, random_state=2)

# %%
pred_train = GB.predict(X_train)
pred_test = GB.predict(X_test)

# %%
get_classification_report(y_train, pred_train, y_test, pred_test)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3609
#            1       1.00      1.00      1.00      1416
#
#     accuracy                           1.00      5025
#    macro avg       1.00      1.00      1.00      5025
# weighted avg       1.00      1.00      1.00      5025
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      1778
#            1       0.51      0.43      0.47       697
#
#     accuracy                           0.72      2475
#    macro avg       0.65      0.63      0.64      2475
# weighted avg       0.71      0.72      0.71      2475
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1485  293
# 1                397  300

# %%
df_1 = pd.read_csv('test_lr_2_processed.csv')
GB = GradientBoostingClassifier(n_estimators=100, learning_rate=1,
                                 max_depth=5, random_state=2)
GB.fit(X_test, y_test)
y_train_preds = GB.predict(df_1)

# %%
nbrs = KNeighborsClassifier(n_neighbors=13)
nbrs.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
pred_train = nbrs.predict(X_train)
pred_test = nbrs.predict(X_test)

# %%
get_classification_report(y_train, pred_train, y_test, pred_test)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.97      0.84      3609
#            1       0.66      0.18      0.28      1416
#
#     accuracy                           0.74      5025
#    macro avg       0.71      0.57      0.56      5025
# weighted avg       0.72      0.74      0.68      5025
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.95      0.82      1778
#            1       0.44      0.10      0.17       697
#
#     accuracy                           0.71      2475
#    macro avg       0.59      0.53      0.50      2475
# weighted avg       0.65      0.71      0.64      2475
#
# CONFUSION MATRIX
#
# col_0              0   1
# Credit Default
# 0               1687  91
# 1                625  72

# %%
# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'learning_rate': [0.1, 0.3, 0.5, 1],
#     'max_depth': [1, 5, 7, 9],
#     'random_state': [5, 6, 7, 8]
# }

# # Инициализация модели
# gs = GridSearchCV(GB, param_grid,
#                   scoring= 'f1', # метрика
#                   cv=5,
#                   n_jobs=-1
#                   )
# gs.fit(X_test, y_test)

# %%
# gs.best_params_

# %%
len(y_train_preds)
# Out:
# 2500

# %%
def save_object_to_csv(obj, filename):
    """
    Сохраняет объект (например, numpy.ndarray, DataFrame или Series) в CSV файл.
    
    :param obj: Объект для сохранения (может быть numpy.ndarray, DataFrame или Series).
    :param filename: Имя файла, в который будет сохранен объект (без расширения).
    """
    # Преобразуем объект в Series, если это numpy.ndarray
    if isinstance(obj, np.ndarray):
        obj = pd.Series(obj)
    
    # Сохраняем в CSV
    obj.to_csv(f"{filename}.csv", index=False)
    print(f"Объект успешно сохранен в {filename}.csv")

# Пример использования:
save_object_to_csv(y_train_preds, 'Предикты для 3й лабы')
# Out:
# Объект успешно сохранен в Предикты для 3й лабы.csv
